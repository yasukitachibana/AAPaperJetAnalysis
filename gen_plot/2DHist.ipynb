# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection='3d')


#file = '../build/sideband_hist_total_ptj120-5020_rapj0.0-2.6_pt0.0-300.0_rap0.0-4.5.txt'
#file = '../SubStrData/JetShapeSubCMS5TeV/5020_PP/sideband_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-8.0_rap0.0-4.5.txt'
#file2 = '../build/count_before_sub_2d_hist_total_ptj120-5020_rapj0.0-2.6_pt0.0-300.0_rap0.0-4.5.txt'

file ='../SubStrData/JetShapeSubCMS5TeV/Tc_160_160/5020_PbPb_0-10_0R25_2R0_1/sideband_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-300.0_rap0.0-4.5.txt'

data = np.loadtxt(file, comments='#')
#data2 = np.loadtxt(file2, comments='#')

ax.set_xlabel(r'$\Delta\phi$', fontsize=13, labelpad=14)
ax.set_ylabel(r'$\Delta\eta$', fontsize=13, labelpad=14)



x = data[:,1]
y = data[:,4]
z = data[:,6]

xlen = len(x[np.where(x==x[0])])
ylen = int(len(x)/xlen)

X=x.reshape((xlen,ylen))
Y=y.reshape((xlen,ylen))
Z=z.reshape((xlen,ylen))


# y = data[:,4]
# z = data[:,6]



# x = y = np.arange(-15, 15, 0.5)
# X, Y = np.meshgrid(x, y)

# sigma = 4
# Z = np.exp(-(X**2 + Y**2)/(2*sigma**2)) / (2*np.pi*sigma**2)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)

fig.savefig("imgb.pdf")
#ax.scatter(X, Y, Z, s=1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection='3d')


#file = '../build/sideband_hist_total_ptj120-5020_rapj0.0-2.6_pt0.0-300.0_rap0.0-4.5.txt'
#file = '../SubStrData/JetShapeSubCMS5TeV/5020_PP/sideband_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-8.0_rap0.0-4.5.txt'
#file2 = '../build/count_before_sub_2d_hist_total_ptj120-5020_rapj0.0-2.6_pt0.0-300.0_rap0.0-4.5.txt'

file ='../SubStrData/JetShapeSubCMS5TeV/5020_PP/sideband_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-300.0_rap0.0-4.5.txt'

data = np.loadtxt(file, comments='#')
#data2 = np.loadtxt(file2, comments='#')

ax.set_xlabel(r'$\Delta\phi$', fontsize=13, labelpad=14)
ax.set_ylabel(r'$\Delta\eta$', fontsize=13, labelpad=14)



x = data[:,1]
y = data[:,4]
z = data[:,6]

xlen = len(x[np.where(x==x[0])])
ylen = int(len(x)/xlen)

X=x.reshape((xlen,ylen))
Y=y.reshape((xlen,ylen))
Z=z.reshape((xlen,ylen))


# y = data[:,4]
# z = data[:,6]



# x = y = np.arange(-15, 15, 0.5)
# X, Y = np.meshgrid(x, y)

# sigma = 4
# Z = np.exp(-(X**2 + Y**2)/(2*sigma**2)) / (2*np.pi*sigma**2)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)

fig.savefig("imgpp.pdf")
#ax.scatter(X, Y, Z, s=1)
