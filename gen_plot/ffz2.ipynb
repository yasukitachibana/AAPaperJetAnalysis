# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams["xtick.minor.visible"] = True 
plt.rcParams["ytick.minor.visible"] = True

# %%
ptj_list = [[126,158],[158,200],[200,251],[251,316]]
ptj_list_dat = [['126','158.488'],['158.488','199.525'],['199.525','251.186'],['251.186','316.224']]

# %%
for ij in range(0,len(ptj_list)):

    ptj = ptj_list[ij]
    ptj_dat = ptj_list_dat[ij]    
    print(ptj)

    fig, axs = plt.subplots(2, 3, figsize=(12, 5.5), sharex='col', sharey='row',
                            gridspec_kw={'hspace': 0, 'wspace': 0,'height_ratios': (5,2.5)})
    (ax1, ax2, ax3), (ax4, ax5, ax6)  = axs

    for ax in axs.flat:
        ax.tick_params(labelsize = 14)
        ax.set_xlabel(r'$z$ ', fontsize=18, labelpad=6)
        ax.tick_params(width = 1, length = 4, pad=5)
        ax.set_xscale("log")
        #ax.set_xticks([10,100])
        ax.label_outer()

    ax1.set_yscale("log")
    #ax4.set_xticks([1,10,100])
    ax4.axhline(1, color = "black", linewidth=0.2, alpha=0.5)
    ax5.axhline(1, color = "black", linewidth=0.2, alpha=0.5)
    ax6.axhline(1, color = "black", linewidth=0.2, alpha=0.5)

    ax1.set_xlim(0.0032,1)
    ax1.set_ylim(0.00001,5000)
    ax4.set_ylim(0.25,1.75)    
    ax1.set_ylabel(r'$D(z)$ ', fontsize=18, labelpad=2)
    ax4.set_ylabel(r'Ratio to Exp. Data', fontsize=13, labelpad=14)


    file1 = '../SubStrData/FFZ/5020_PP/ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
    filed = '../exp_data/hepdata_atlas_jet_ff_5tev/DzRE_jetfragmentationfunction_pTjet_'+str(ptj_dat[0])+'-'+str(ptj_dat[1])+'_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_pp.txt'
    data1 = np.loadtxt(file1, comments='#')
    datad = np.loadtxt(filed, comments='#')
    


    xst = len(data1[:,0])-len(datad[:,0])
    
    
    x1 = data1[xst:,1]
    y1 = data1[xst:,3]
    y1err = data1[xst:,4]
    x1step = np.append(data1[xst:,0],data1[-1,2])
    y1step = np.append(data1[xst:,3],data1[-1,3])

    xd = datad[:,0]
    yd = datad[:,3]
    yderr = datad[:,4]
    xdstep = np.append(datad[:,1],datad[-1,2])
    ydstep = np.append(datad[:,3],datad[-1,3])


    ydsysp = np.append(datad[:,6],datad[-1,6])
    ydsysm = np.append(datad[:,7],datad[-1,7])


    ax1.errorbar(xd, yd, yerr=yderr, marker="o", linestyle="none", color = 'black',label='ATLAS \n[PRC 98, no.2, 024908 (2018)]')
    ax1.fill_between(xdstep, ydstep+ydsysm, ydstep+ydsysp, step='post', color='k', alpha=0.15)
    
    ax1.step(x1step, y1step, where='post', label='MATTER', color='green',linestyle='dotted', linewidth = 2)
    ax1.errorbar(x1, y1, yerr=y1err, marker="", linestyle="none")
    #######
    ax4.errorbar(xd, yd/yd, yerr=yderr/yd, marker="o", linestyle="none", color = 'black')
    ax4.fill_between(xdstep, (ydstep+ydsysm)/ydstep, (ydstep+ydsysp)/ydstep, step='post', color='k', alpha=0.15)
    ax4.step(x1step, y1step/ydstep, where='post', color='green',linestyle='dotted', linewidth = 2)
    ax4.errorbar(x1, y1/yd, yerr=y1err/yd, marker="", linestyle="none")
#     ######################################################################
    
    file1 = '../SubStrData/FFZ/Type5_qhatA10_B0_0p30_Q2p0/OutputFile/ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
    file2 = '../SubStrData/FFZ/Type5_qhatA10_B100_0p30_Q2p0/OutputFile/ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
    file3 = '../SubStrData/FFZ/RunningAlphas_MATTER_Vacuum_LBT/OutputFile_5020_PbPb_0-10_0.35_2.0_1/ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
    filed = '../exp_data/hepdata_atlas_jet_ff_5tev/DzRE_jetfragmentationfunction_pTjet_'+str(ptj_dat[0])+'-'+str(ptj_dat[1])+'_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_0-10.txt'

    data1 = np.loadtxt(file1, comments='#')
    data2 = np.loadtxt(file2, comments='#')
    data3 = np.loadtxt(file3, comments='#')
    datad = np.loadtxt(filed, comments='#')

    xst = len(data1[:,0])-len(datad[:,0])

    x1 = data1[xst:,1]
    y1 = data1[xst:,3]
    y1err = data1[xst:,4]
    x1step = np.append(data1[xst:,0],data1[-1,2])
    y1step = np.append(data1[xst:,3],data1[-1,3])

    x2 = data2[xst:,1]
    y2 = data2[xst:,3]
    y2err = data2[xst:,4]
    x2step = np.append(data2[xst:,0],data2[-1,2])
    y2step = np.append(data2[xst:,3],data2[-1,3])
    
    x3 = data3[xst:,1]
    y3 = data3[xst:,3]
    y3err = data3[xst:,4]
    x3step = np.append(data3[xst:,0],data3[-1,2])
    y3step = np.append(data3[xst:,3],data3[-1,3])    

    xd = datad[:,0]
    yd = datad[:,3]
    yderr = datad[:,4]
    xdstep = np.append(datad[:,1],datad[-1,2])
    ydstep = np.append(datad[:,3],datad[-1,3])

    ydsysp = np.append(datad[:,6],datad[-1,6])
    ydsysm = np.append(datad[:,7],datad[-1,7])

    ax2.errorbar(xd, yd, yerr=yderr, marker="o", linestyle="none", color = 'black')
    ax2.fill_between(xdstep, ydstep+ydsysm, ydstep+ydsysp, step='post', color='black', alpha=0.15)

    ax2.step(x1step, y1step, where='post', label='MATTER+LBT'+'\n'+r'$c_1=10,c_2=0,\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.3$', color='deeppink',linewidth = 2)
    ax2.errorbar(x1, y1, yerr=y1err, marker="", linestyle="none", color='deeppink',linewidth = 2)

    ax2.step(x2step, y2step, where='post', label='MATTER+LBT'+'\n'+r'$c_1=10,c_2=100,\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.3$', linestyle='dashed', color='slateblue',linewidth = 2)
    ax2.errorbar(x2, y2, yerr=y2err, marker="", linestyle="none", color='slateblue',linewidth = 2)

    ax2.step(x3step, y3step, where='post', label='MATTER(vacuum)+LBT'+'\n'+r'$c_1=0,c_2=0,\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.35$', linestyle='dashdot', color='olive',linewidth = 2)
    ax2.errorbar(x3, y3, yerr=y3err, marker="", linestyle="none", color='olive',linewidth = 2)


    #######
    ax5.errorbar(xd, yd/yd, yerr=yderr/yd, marker="o", linestyle="none", color = 'black')
    ax5.fill_between(xdstep, (ydstep+ydsysm)/ydstep, (ydstep+ydsysp)/ydstep, step='post', color='k', alpha=0.15)

    ax5.step(x1step, y1step/ydstep, where='post', color='deeppink',linewidth = 2)
    ax5.errorbar(x1, y1/yd, yerr=y1err/yd, marker="", linestyle="none", color='deeppink',linewidth = 2)

    ax5.step(x2step, y2step/ydstep, where='post', linestyle='dashed', color='slateblue',linewidth = 2)
    ax5.errorbar(x2, y2/yd, yerr=y2err/yd, marker="", linestyle="none", color='slateblue',linewidth = 2)

    ax5.step(x3step, y3step/ydstep, where='post', linestyle='dashdot', color='olive',linewidth = 2)
    ax5.errorbar(x3, y3/yd, yerr=y3err/yd, marker="", linestyle="none", color='olive',linewidth = 2)


    
    file1 = '../SubStrData/FFZ/Tc_160_160/5020_PbPb_0-10_0R25_2R0_1/ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
    file2 = '../SubStrData/FFZ/Tc_160_160/5020_PbPb_0-10_0R25_2R0_0/ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
    filed = '../exp_data/hepdata_atlas_jet_ff_5tev/DzRE_jetfragmentationfunction_pTjet_'+str(ptj_dat[0])+'-'+str(ptj_dat[1])+'_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_0-10.txt'

    data1 = np.loadtxt(file1, comments='#')
    data2 = np.loadtxt(file2, comments='#')
    datad = np.loadtxt(filed, comments='#')

    xst = len(data1[:,0])-len(datad[:,0])

    x1 = data1[xst:,1]
    y1 = data1[xst:,3]
    y1err = data1[xst:,4]
    x1step = np.append(data1[xst:,0],data1[-1,2])
    y1step = np.append(data1[xst:,3],data1[-1,3])

    x2 = data2[xst:,1]
    y2 = data2[xst:,3]
    y2err = data2[xst:,4]
    x2step = np.append(data2[xst:,0],data2[-1,2])
    y2step = np.append(data2[xst:,3],data2[-1,3])

    xd = datad[:,0]
    yd = datad[:,3]
    yderr = datad[:,4]
    xdstep = np.append(datad[:,1],datad[-1,2])
    ydstep = np.append(datad[:,3],datad[-1,3])

    ydsysp = np.append(datad[:,6],datad[-1,6])
    ydsysm = np.append(datad[:,7],datad[-1,7])

    ax3.errorbar(xd, yd, yerr=yderr, marker="o", linestyle="none", color = 'black')
    ax3.fill_between(xdstep, ydstep+ydsysm, ydstep+ydsysp, step='post', color='black', alpha=0.15)

    ax3.step(x1step, y1step, where='post', label='MATTER+LBT\n no running '+r'$\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.25$', color='red',linewidth = 2)
    ax3.errorbar(x1, y1, yerr=y1err, marker="", linestyle="none", color='red',linewidth = 2)

    ax3.step(x2step, y2step, where='post', label='MATTER+LBT w/o recoils\n no running '+r'$\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.25$', linestyle='dashed', color='blue',linewidth = 2)
    ax3.errorbar(x2, y2, yerr=y2err, marker="", linestyle="none", color='blue',linewidth = 2)
    #######
    ax6.errorbar(xd, yd/yd, yerr=yderr/yd, marker="o", linestyle="none", color = 'black')
    ax6.fill_between(xdstep, (ydstep+ydsysm)/ydstep, (ydstep+ydsysp)/ydstep, step='post', color='k', alpha=0.15)
    
    ax6.step(x1step, y1step/ydstep, where='post', color='red',linewidth = 2)
    ax6.errorbar(x1, y1/yd, yerr=y1err/yd, marker="", linestyle="none", color='red',linewidth = 2)

    ax6.step(x2step, y2step/ydstep, where='post', linestyle='dashed', color='blue',linewidth = 2)
    ax6.errorbar(x2, y2/yd, yerr=y2err/yd, marker="", linestyle="none", color='blue',linewidth = 2)

    xmin = datad[0,1]
    xmax = datad[-1,2]    

    for ax in axs.flat:    
        ax.set_xlim(xmin,xmax)        
    
    def xlength(a):
        return xmin*pow(xmax/xmin,a)
    
    
    ax1.text(xlength(0.98), 800, r'$pp,\,5.02$ TeV', fontsize = 18, ha = 'right')
    ax2.text(xlength(0.98), 800, r'PbPb ($0$-$10\%$), $5.02$ TeV', fontsize = 18, ha = 'right')
    ax3.text(xlength(0.98), 800, r'PbPb ($0$-$10\%$), $5.02$ TeV', fontsize = 18, ha = 'right')

    ax1.text(xlength(0.05), 0.05, str(ptj[0])+r'$<p_{\mathrm{T}}^{\mathrm{jet}}<$'+str(ptj[1])+r' GeV'+'\n'+r'$|y_{\mathrm {jet}}|<0.3$', fontsize = 15, ha = 'left')
    ax3.text(xlength(0.05), 0.15, r'anti-$k_t$, $R=0.4$'+'\n'+r'$p_{\mathrm{T}}^{\mathrm{trk}}>1.0$ GeV', fontsize = 15, ha = 'left')
    ax2.text(xlength(0.99), 30, r'$Q_{\mathrm{switch}}=2$ GeV'+'\n'+r'$T_{\mathrm{c}}=0.16$ GeV', fontsize = 14, ha = 'right')


    ax1.legend(bbox_to_anchor=(-0.02, -0.05),borderaxespad=1,handlelength=1.3, handletextpad=0.5,loc='lower left', fontsize=14,edgecolor='none', frameon=True, facecolor='none')
    ax2.legend(bbox_to_anchor=(-0.02, -0.05), borderaxespad=1,handlelength=1.3, handletextpad=0.5,loc='lower left', fontsize=14,edgecolor='none', frameon=True, facecolor='none')
    ax3.legend(bbox_to_anchor=(-0.02, -0.05), borderaxespad=1,handlelength=1.3, handletextpad=0.5,loc='lower left', fontsize=14,edgecolor='none', frameon=True, facecolor='none')

    plt.tight_layout()
    plt.savefig('new_Dz_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3.pdf')

# import os
# os.system('open .')
# Out:
# [126, 158]
# [158, 200]
# [200, 251]
# [251, 316]

# %%
cent_list = [[0,10]]

for cent in cent_list:
    
    fig, axs = plt.subplots(1, 4, figsize=(16, 4), sharex='col', sharey='row', gridspec_kw={'hspace': 0, 'wspace': 0})
    (ax1, ax2, ax3, ax4)  = axs

    for ax in axs.flat:
        ax.tick_params(labelsize = 14)
        ax.set_xlabel(r'$z$ ', fontsize=18, labelpad=6)
        ax.tick_params(width = 1, length = 4, pad=5)
        ax.set_xscale("log")
        ax.set_xticks([0.01,0.1,1])        
        ax.axhline(1, color = "black", linewidth=0.2, alpha=0.5)
        ax.label_outer()
    

    ax1.set_ylabel(r'$R_{D(z)}$ ', fontsize=18, labelpad=2)


    
    for i in range(0,4):
        
        ptj = ptj_list[i]
        ptj_dat = ptj_list_dat[i]
        
        file1 = '../SubStrData/FFZ/Type5_qhatA10_B0_0p30_Q2p0/OutputFile/raa_ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
        file2 = '../SubStrData/FFZ/Type5_qhatA10_B100_0p30_Q2p0/OutputFile/raa_ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
        file3 = '../SubStrData/FFZ/RunningAlphas_MATTER_Vacuum_LBT/OutputFile_5020_PbPb_0-10_0.35_2.0_1/raa_ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
        filed = '../exp_data/hepdata_atlas_jet_ff_5tev/R_DzRE_ratioofjetfragmentationfunctioncomparedtoppcollisions_pTjet_'+str(ptj_dat[0])+'-'+str(ptj_dat[1])+'_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_0-10.txt'

        data1 = np.loadtxt(file1, comments='#')
        data2 = np.loadtxt(file2, comments='#')
        data3 = np.loadtxt(file3, comments='#')
        datad = np.loadtxt(filed, comments='#')

        xst = len(data1[:,0])-len(datad[:,0])

        x1 = data1[xst:,1]
        y1 = data1[xst:,3]
        y1err = data1[xst:,4]
        x1step = np.append(data1[xst:,0],data1[-1,2])
        y1step = np.append(data1[xst:,3],data1[-1,3])

        x2 = data2[xst:,1]
        y2 = data2[xst:,3]
        y2err = data2[xst:,4]
        x2step = np.append(data2[xst:,0],data2[-1,2])
        y2step = np.append(data2[xst:,3],data2[-1,3])
    
        x3 = data3[xst:,1]
        y3 = data3[xst:,3]
        y3err = data3[xst:,4]
        x3step = np.append(data3[xst:,0],data3[-1,2])
        y3step = np.append(data3[xst:,3],data3[-1,3])    

        xd = datad[:,0]
        yd = datad[:,3]
        yderr = datad[:,4]
        xdstep = np.append(datad[:,1],datad[-1,2])
        ydstep = np.append(datad[:,3],datad[-1,3])

        ydsysp = np.append(datad[:,6],datad[-1,6])
        ydsysm = np.append(datad[:,7],datad[-1,7])




        
        lab1 = ''
        lab2 = ''
        lab3 = ''
        labd = ''
        if i == 0:
            lab1 = 'MATTER+LBT'+'\n'+r'$c_1=10,c_2=0,\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.3$'
            lab2 = 'MATTER+LBT'+'\n'+r'$c_1=10,c_2=100,\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.3$'
        if i == 1:
            lab3 = 'MATTER(vacuum)+LBT'+'\n'+r'$c_1=0,c_2=0,\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.35$'
            labd = 'ATLAS \n[PRC 98, no.2, 024908 (2018)]'

            


        axs[i].step(x1step, y1step, where='post', label=lab1, color='deeppink',linewidth = 2)
        axs[i].errorbar(x1, y1, yerr=y1err, marker="", linestyle="none", color='deeppink',linewidth = 2)

        axs[i].step(x2step, y2step, where='post', label=lab2, linestyle='dashed', color='slateblue',linewidth = 2)
        axs[i].errorbar(x2, y2, yerr=y2err, marker="", linestyle="none", color='slateblue',linewidth = 2)

        axs[i].step(x3step, y3step, where='post', label=lab3, linestyle='dashdot', color='olive',linewidth = 2)
        axs[i].errorbar(x3, y3, yerr=y3err, marker="", linestyle="none", color='olive',linewidth = 2)

        axs[i].errorbar(xd, yd, yerr=yderr, label=labd, marker="o", linestyle="none", color = 'black')
        axs[i].fill_between(xdstep, ydstep+ydsysm, ydstep+ydsysp, step='post', color='black', alpha=0.15)
        
        xmin = datad[0,1]
        xmax = datad[-1,2]

        axs[i].set_xlim(xmin,xmax)
        axs[i].set_ylim(0.5,2.75)
        
        def xlength(a):
            return xmin*pow(xmax/xmin,a)        
        
        axs[i].text(xlength(0.05), 2.55, str(ptj[0])+r'$<p_{\mathrm{T}}^{\mathrm{jet}}<$'+str(ptj[1])+r' GeV', fontsize = 18, ha = 'left')

        if i == 0:
            axs[i].legend(bbox_to_anchor=(0.9, 0.925), borderaxespad=1,handlelength=1.3, handletextpad=0.5,loc='upper right', fontsize=14,edgecolor='none', frameon=True, facecolor='none')
        if i == 1:
            axs[i].legend(bbox_to_anchor=(0.92, 0.925), borderaxespad=1,handlelength=1.3, handletextpad=0.5,loc='upper right', fontsize=14,edgecolor='none', frameon=True, facecolor='none')


            #     ######################################################################
    axs[0].text(0.012, 0.55, r'PbPb ('+str(cent[0])+'-'+str(cent[1])+'$\%$), $5.02$ TeV', fontsize = 18, ha = 'left')

    

    axs[2].text(0.02, 1.7, r'$|y_{\mathrm {jet}}|<0.3$'+'\n'+r'anti-$k_t$, $R=0.4$'+'\n'+r'$p_{\mathrm{T}}^{\mathrm{trk}}>1.0$ GeV', fontsize = 16, ha = 'left')
    axs[3].text(0.02, 1.97, r'$Q_{\mathrm{switch}}=2$ GeV', fontsize = 16, ha = 'left')
    axs[3].text(0.02, 1.8, r'$T_{\mathrm{c}}=0.16$ GeV', fontsize = 14, ha = 'left')

    plt.tight_layout()
    plt.savefig('new_raa_Dz_ptj'+str(cent[0])+'-'+str(cent[1])+'_rapj0.0-0.3.pdf')

# import os
# os.system('open .')

# %%
cent_list = [[0,10],[30,40]]

for cent in cent_list:
    
    fig, axs = plt.subplots(1, 4, figsize=(16, 4), sharex='col', sharey='row', gridspec_kw={'hspace': 0, 'wspace': 0})
    (ax1, ax2, ax3, ax4)  = axs

    for ax in axs.flat:
        ax.tick_params(labelsize = 14)
        ax.set_xlabel(r'$z$ ', fontsize=18, labelpad=6)
        ax.tick_params(width = 1, length = 4, pad=5)
        ax.set_xscale("log")
        ax.set_xticks([0.01,0.1,1])
        ax.axhline(1, color = "black", linewidth=0.2, alpha=0.5)
        ax.label_outer()
    

    ax1.set_ylabel(r'$R_{D(z)}$ ', fontsize=18, labelpad=2)


    
    for i in range(0,4):
        
        ptj = ptj_list[i]
        ptj_dat = ptj_list_dat[i]        

        file1 = '../SubStrData/FFZ/Tc_160_160/5020_PbPb_'+str(cent[0])+'-'+str(cent[1])+'_0R25_2R0_1/raa_ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
        file2 = '../SubStrData/FFZ/Tc_160_160/5020_PbPb_'+str(cent[0])+'-'+str(cent[1])+'_0R25_2R0_0/raa_ffz_hist_total_ptj'+str(ptj[0])+'-'+str(ptj[1])+'_rapj0.0-0.3_pt1.0-398.0_rap0.0-3.0.txt'
        
        filed = '../exp_data/hepdata_atlas_jet_ff_5tev/R_DzRE_ratioofjetfragmentationfunctioncomparedtoppcollisions_pTjet_'+str(ptj_dat[0])+'-'+str(ptj_dat[1])+'_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_'+str(cent[0])+'-'+str(cent[1])+'.txt'
        print(filed)
        data1 = np.loadtxt(file1, comments='#')
        data2 = np.loadtxt(file2, comments='#')
        data3 = np.loadtxt(file3, comments='#')
        datad = np.loadtxt(filed, comments='#')

        xst = len(data1[:,0])-len(datad[:,0])

        x1 = data1[xst:,1]
        y1 = data1[xst:,3]
        y1err = data1[xst:,4]
        x1step = np.append(data1[xst:,0],data1[-1,2])
        y1step = np.append(data1[xst:,3],data1[-1,3])

        x2 = data2[xst:,1]
        y2 = data2[xst:,3]
        y2err = data2[xst:,4]
        x2step = np.append(data2[xst:,0],data2[-1,2])
        y2step = np.append(data2[xst:,3],data2[-1,3])
    
        x3 = data3[xst:,1]
        y3 = data3[xst:,3]
        y3err = data3[xst:,4]
        x3step = np.append(data3[xst:,0],data3[-1,2])
        y3step = np.append(data3[xst:,3],data3[-1,3])    

        xd = datad[:,0]
        yd = datad[:,3]
        yderr = datad[:,4]
        xdstep = np.append(datad[:,1],datad[-1,2])
        ydstep = np.append(datad[:,3],datad[-1,3])

        ydsysp = np.append(datad[:,6],datad[-1,6])
        ydsysm = np.append(datad[:,7],datad[-1,7])


        
#         axs[i].errorbar(xd, yd, yerr=yderr, marker="o", linestyle="none", color = 'black',label='ATLAS \n[PRC 98, no.2, 024908 (2018)]')
#         axs[i].fill_between(xdstep, ydstep+ydsysm, ydstep+ydsysp, step='post', color='black', alpha=0.15)

        axs[i].errorbar(xd, yd, yerr=yderr, marker="o", linestyle="none", color = 'black')
        axs[i].fill_between(xdstep, ydstep+ydsysm, ydstep+ydsysp, step='post', color='black', alpha=0.15)


        axs[i].step(x1step, y1step, where='post', label='MATTER+LBT\n no running '+r'$\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.25$', color='red',linewidth = 2)
        axs[i].errorbar(x1, y1, yerr=y1err, marker="", linestyle="none", color='red',linewidth = 2)

        axs[i].step(x2step, y2step, where='post', label='MATTER+LBT w/o recoils\n no running '+r'$\alpha^{\mathrm{fix}}_{\mathrm{s}}=0.25$', linestyle='dashed', color='blue',linewidth = 2)
        axs[i].errorbar(x2, y2, yerr=y2err, marker="", linestyle="none", color='blue',linewidth = 2)



        
        xmin = datad[0,1]
        xmax = datad[-1,2]

        axs[i].set_xlim(xmin,xmax)
        axs[i].set_ylim(0.5,2.5)
        
        def xlength(a):
            return xmin*pow(xmax/xmin,a)        
        
        axs[i].text(xlength(0.05), 2.325, str(ptj[0])+r'$<p_{\mathrm{T}}^{\mathrm{jet}}<$'+str(ptj[1])+r' GeV', fontsize = 18, ha = 'left')

#     ######################################################################
    axs[0].legend(bbox_to_anchor=(0.9, 0.925), borderaxespad=1,handlelength=1.3, handletextpad=0.5,loc='upper right', fontsize=14,edgecolor='none', frameon=True, facecolor='none')
            #     ######################################################################
    axs[0].text(0.012, 0.55, r'PbPb ('+str(cent[0])+'-'+str(cent[1])+'$\%$), $5.02$ TeV', fontsize = 18, ha = 'left')

    

    axs[2].text(0.02, 1.7, r'$|y_{\mathrm {jet}}|<0.3$'+'\n'+r'anti-$k_t$, $R=0.4$'+'\n'+r'$p_{\mathrm{T}}^{\mathrm{trk}}>1.0$ GeV', fontsize = 16, ha = 'left')
    axs[3].text(0.02, 1.97, r'$Q_{\mathrm{switch}}=2$ GeV', fontsize = 16, ha = 'left')
    axs[3].text(0.02, 1.8, r'$T_{\mathrm{c}}=0.16$ GeV', fontsize = 14, ha = 'left')
    
    plt.tight_layout()
    plt.savefig('old_raa_Dz_ptj'+str(cent[0])+'-'+str(cent[1])+'_rapj0.0-0.3.pdf')

# import os
# os.system('open .')
# Out:
# ../exp_data/hepdata_atlas_jet_ff_5tev/R_DzRE_ratioofjetfragmentationfunctioncomparedtoppcollisions_pTjet_126-158.488_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_0-10.txt
# ../exp_data/hepdata_atlas_jet_ff_5tev/R_DzRE_ratioofjetfragmentationfunctioncomparedtoppcollisions_pTjet_158.488-199.525_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_0-10.txt
# ../exp_data/hepdata_atlas_jet_ff_5tev/R_DzRE_ratioofjetfragmentationfunctioncomparedtoppcollisions_pTjet_199.525-251.186_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_0-10.txt
# ../exp_data/hepdata_atlas_jet_ff_5tev/R_DzRE_ratioofjetfragmentationfunctioncomparedtoppcollisions_pTjet_251.186-316.224_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_0-10.txt
# ../exp_data/hepdata_atlas_jet_ff_5tev/R_DzRE_ratioofjetfragmentationfunctioncomparedtoppcollisions_pTjet_126-158.488_abs.rapidityjet_0-0.3_SQRTS_GeV_5020.0_Centrality_30-40.txt
# ...
