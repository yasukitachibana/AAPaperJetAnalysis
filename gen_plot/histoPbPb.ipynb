# %%
import numpy as np

lim = [-0.01,0.05]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection='3d')



file ='/Users/yasukitachibana/GoogleDrive/Codes/AAPaperJetAnalysis/SubStrData/'
file = file + 'JetShapeLowReso/MATTER_LBT_RunningAlphaS_Q2qhat/OutputFile_Type5_qhatA10_B0_5020_PbPb_0-10_0.30_2.0_1/'
file = file + 'count_before_sub_2d_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-1.0_rap0.0-4.6.txt'


data = np.loadtxt(file, comments='#')
#data2 = np.loadtxt(file2, comments='#')

ax.set_xlabel(r'$\Delta\phi$', fontsize=13, labelpad=14)
ax.set_ylabel(r'$\Delta\eta$', fontsize=13, labelpad=14)



x = data[:,0]
dx = data[:,2]-data[:,0]
y = data[:,3]
dy = data[:,5]-data[:,3]
dz = data[:,6]
z = np.zeros_like(dz)

cmap = cm.get_cmap('jet') # Get desired colormap - you can change this!
max_height = np.max(dz)   # get range of colorbars so we can normalize
min_height = np.min(dz)
# scale each z to [0,1], and get their rgb values

rgba = [cmap((k-lim[0])/lim[1]) for k in dz] 

#ax.set_zlim(lim[0],lim[1])

ax.bar3d(x, y, z, dx, dy, dz, color=rgba, zsort='average')
fig.savefig("pbpb_full_rap.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection='3d')



file ='/Users/yasukitachibana/GoogleDrive/Codes/AAPaperJetAnalysis/SubStrData/'
file = file + 'JetShapeLowReso/MATTER_LBT_RunningAlphaS_Q2qhat/OutputFile_Type5_qhatA10_B0_5020_PbPb_0-10_0.30_2.0_1/'
file = file + 'count_before_sub_2d_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-1.0_rap0.0-2.4.txt'


data = np.loadtxt(file, comments='#')
#data2 = np.loadtxt(file2, comments='#')

ax.set_xlabel(r'$\Delta\phi$', fontsize=13, labelpad=14)
ax.set_ylabel(r'$\Delta\eta$', fontsize=13, labelpad=14)



x = data[:,0]
dx = data[:,2]-data[:,0]
y = data[:,3]
dy = data[:,5]-data[:,3]
dz = data[:,6]
z = np.zeros_like(dz)

cmap = cm.get_cmap('jet') # Get desired colormap - you can change this!
max_height = np.max(dz)   # get range of colorbars so we can normalize
min_height = np.min(dz)
# scale each z to [0,1], and get their rgb values
rgba = [cmap((k-lim[0])/lim[1]) for k in dz] 

#ax.set_zlim(lim[0],lim[1])

ax.bar3d(x, y, z, dx, dy, dz, color=rgba, zsort='average')
fig.savefig("pbpb_rap24.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection='3d')


file ='/Users/yasukitachibana/GoogleDrive/Codes/AAPaperJetAnalysis/SubStrData/'
file = file + 'JetShapeLowReso/MATTER_LBT_RunningAlphaS_Q2qhat/OutputFile_Type5_qhatA10_B0_5020_PbPb_0-10_0.30_2.0_1/'
file = file + 'count_2d_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-1.0_rap0.0-4.6.txt'


data = np.loadtxt(file, comments='#')
#data2 = np.loadtxt(file2, comments='#')

ax.set_xlabel(r'$\Delta\phi$', fontsize=13, labelpad=14)
ax.set_ylabel(r'$\Delta\eta$', fontsize=13, labelpad=14)



x = data[:,0]
dx = data[:,2]-data[:,0]
y = data[:,3]
dy = data[:,5]-data[:,3]
dz = data[:,6]
z = np.zeros_like(dz)

cmap = cm.get_cmap('jet') # Get desired colormap - you can change this!
max_height = np.max(dz)   # get range of colorbars so we can normalize
min_height = np.min(dz)
# scale each z to [0,1], and get their rgb values


rgba = [cmap((k-lim[0])/lim[1]) for k in dz] 

#ax.set_zlim(lim[0],lim[1])

ax.bar3d(x, y, z, dx, dy, dz, color=rgba, zsort='average')
fig.savefig("pbpb_after_sideband.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection='3d')



file ='/Users/yasukitachibana/GoogleDrive/Codes/AAPaperJetAnalysis/SubStrData/'
file = file + 'JetShapeLowReso/MATTER_LBT_RunningAlphaS_Q2qhat/OutputFile_Type5_qhatA10_B0_5020_PbPb_0-10_0.30_2.0_1/'


file = file + 'sideband_hist_total_ptj120-5020_rapj0.0-1.6_pt0.7-1.0_rap0.0-4.6.txt'


data = np.loadtxt(file, comments='#')
#data2 = np.loadtxt(file2, comments='#')

ax.set_xlabel(r'$\Delta\phi$', fontsize=13, labelpad=14)
ax.set_ylabel(r'$\Delta\eta$', fontsize=13, labelpad=14)



x = data[:,0]
dx = data[:,2]-data[:,0]
y = data[:,3]
dy = data[:,5]-data[:,3]
dz = data[:,6]
z = np.zeros_like(dz)

cmap = cm.get_cmap('jet') # Get desired colormap - you can change this!
max_height = np.max(dz)   # get range of colorbars so we can normalize
min_height = np.min(dz)
# scale each z to [0,1], and get their rgb values

rgba = [cmap((k-lim[0])/lim[1]) for k in dz] 

ax.set_zlim(lim[0],lim[1])


ax.bar3d(x, y, z, dx, dy, dz, color=rgba, zsort='average')
fig.savefig("pbpb_sideband.pdf")
